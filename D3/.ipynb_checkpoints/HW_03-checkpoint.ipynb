# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 解題步驟：
#
# 1. 將 train.csv, test.csv 合併
# 2. 取出 LotFrontage, GarageYrBlt, MasVnrArea 三個特徵的資料
# 3. 分別以平均值及中位數來填補缺失值
# 4. 分析缺失值，練習繪製直方圖及機率圖 (如下圖)
# 5. 分別計算原本、以平均值填補、以中位數填補的標準差
# 6. 課後問答
#
# <img src="./data/hist_plot.png" style="zoom:100%;" />
#
# ## Hint
#
# * [pandas.DataFrame.fillna()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html)
# * [seaborn.histplot](
#
#
# ## 讀取資料

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
total = pd.concat([train, test], axis = 0)
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1      757          60       RL         68.0    10769   Pave   NaN      IR1
# 2      632         120       RL         34.0     4590   Pave   NaN      Reg
# 3     1193          50       RM         60.0     9600   Pave  Grvl      Reg
# 4      773          80       RL         94.0     7819   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1090  1361          70       RL         51.0     9842   Pave   NaN      Reg
# 1091     9          50       RM         51.0     6120   Pave   NaN      Reg
# 1092   382          20       FV         60.0     7200   Pave  Pave      Reg
# 1093  1414          20       RL         88.0    10994   Pave   NaN      IR1
# 1094   951          20       RL         60.0     7200   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ## 分離目標

# %%
# 將目標分析欄位取出來
target1 = [total.LotFrontage]
target2 = [total.GarageYrBlt]
target3 = [total.MasVnrArea]

# %%
# 以平均值來填補缺失值
target1.append(target1[0].fillna(target1[0].mean()))
target2.append(target2[0].fillna(target2[0].mean()))
target3.append(target3[0].fillna(target3[0].mean()))
# 以中位數來填補缺失值
target1.append(target1[0].fillna(target1[0].median()))
target2.append(target2[0].fillna(target2[0].median()))
target3.append(target3[0].fillna(target3[0].median()))

# %% [markdown]
# ## 繪圖

# %%
# 繪圖
label = ['Origin', 'Mean', 'Median']
color = ['tab:blue', 'tab:orange', 'tab:green']

plt.figure(figsize = (20, 5), dpi = 80)
plt.subplot(1, 3, 1)
for i in range(3):
    sns.histplot(target1[i], kde = True, stat = 'probability', element = 'bars', label = label[i], color = color[i])
plt.legend()

plt.subplot(1, 3, 2)
for i in range(3):
    sns.histplot(target2[i], kde = True, stat = 'probability', element = 'bars', label = label[i], color = color[i])
plt.legend()

plt.subplot(1, 3, 3)
for i in range(3):
    sns.histplot(target3[i], kde = True, stat = 'probability', element = 'bars', label = label[i], color = color[i])
plt.legend()

plt.show()

# %% [markdown]
# ## 分析標準差

# %%
for i in range(3):
    print(label[i],":")
    print('Lotfrontage:', target1[i].std(),'GarageYrBlt:', target2[i].std(),'MasVnrArea:', target3[i].std())
# Out:
# Origin :
# Lotfrontage: 22.02402268870693 GarageYrBlt: 23.994583259057613 MasVnrArea: 180.5691124259731
# Mean :
# Lotfrontage: 22.02402268870693 GarageYrBlt: 23.994583259057613 MasVnrArea: 180.5691124259731
# Median :
# Lotfrontage: 22.02402268870693 GarageYrBlt: 23.994583259057613 MasVnrArea: 180.5691124259731

# %% [markdown]
# ## 透過分析標準差可以得到什麼結果？
